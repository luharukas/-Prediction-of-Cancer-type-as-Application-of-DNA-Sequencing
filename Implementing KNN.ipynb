# %%
#Implementing KNN

# %%
# Run this cell to get preprocessed data
# %run Dimension_Reduction.ipynb
# Out:
# Data loaded
# **************Details of data*************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Columns: 20532 entries, Unnamed: 0 to gene_20530
# dtypes: float64(20531), object(1)
# memory usage: 125.5+ MB
# None
#
# **************Details of labels*************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  801 non-null    object
#  1   Class       801 non-null    object
# dtypes: object(2)
# memory usage: 12.6+ KB
# None
# Unnamed: 0    801
# Class           5
# dtype: int64
# Null details
# ************For Data***********
# Unnamed: 0    0
# gene_0        0
# gene_1        0
# gene_2        0
# gene_3        0
#              ..
# gene_20526    0
# gene_20527    0
# gene_20528    0
# gene_20529    0
# gene_20530    0
# Length: 20532, dtype: int64
#
# ...

# %%
# splitting dataset into training and testing part
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score
test_data_ratio=[0.3,0.25,0.2,0.15,0.1,0.05]
for i in test_data_ratio:
    print("******************Start of iteration******************\n")
    print("For ratio ",i)
    X_train, X_test, y_train, y_test=train_test_split(final_data.iloc[:,:80],final_data['label'],test_size=i,shuffle=True)
    for n in [5,10,15,20,25,30,35,40]:
        knn_model = KNeighborsClassifier(n_neighbors=5,leaf_size=n)
        knn_model.fit(X_train, y_train)
        arr=cross_val_score(knn_model,X_train,y_train,cv=4)
        print(arr.mean())
    
    #Predict the response for test dataset
    y_pred = knn_model.predict(X_test)
    print(confusion_matrix(y_test,y_pred))
    print("\n")
    #print(classification_report(y_test,y_pred))
    print("Training set score for KNN: %f" % knn_model.score(X_train , y_train))
    print("Testing  set score for KNN: %f" % knn_model.score(X_test  , y_test ))

    print("******************End of iteration******************\n")
# Out:
# ******************Start of iteration******************
#
# For ratio  0.3
# 0.925
# 0.925
# 0.925
# 0.925
# 0.925
# 0.925
# 0.925
# 0.925
# [[87  0  0  2  0]
#  [ 0 21  0  0  0]
#  [ 4  0 47  0  1]
#  [ 4  0  0 33  1]
#  [ 0  0  0  0 41]]
#
#
# Training set score for KNN: 0.951786
# Testing  set score for KNN: 0.950207
# ******************End of iteration******************
#
# ******************Start of iteration******************
#
# For ratio  0.25
# 0.9316666666666668
# 0.9316666666666668
# 0.9316666666666668
# 0.9316666666666668
# 0.9316666666666668
# 0.9316666666666668
# 0.9316666666666668
# 0.9316666666666668
# [[82  0  0  3  0]
#  [ 0 12  0  0  0]
#  [ 2  0 39  0  0]
#  [ 5  0  0 24  0]
#  [ 0  0  0  0 34]]
#
#
# Training set score for KNN: 0.945000
# Testing  set score for KNN: 0.950249
# ******************End of iteration******************
#
# ******************Start of iteration******************
#
# For ratio  0.2
# 0.9359375000000001
# 0.9359375000000001
# ...
