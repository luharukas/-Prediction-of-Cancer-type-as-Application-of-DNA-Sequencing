# %% [markdown]
# # Implementation of Gaussian NB + Adaboost

# %%
# Run this cell to get preprocessed data
# %run Dimension_Reduction.ipynb
# Out:
# Data loaded
# **************Details of data*************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Columns: 20532 entries, Unnamed: 0 to gene_20530
# dtypes: float64(20531), object(1)
# memory usage: 125.5+ MB
# None
#
# **************Details of labels*************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  801 non-null    object
#  1   Class       801 non-null    object
# dtypes: object(2)
# memory usage: 12.6+ KB
# None
# Unnamed: 0    801
# Class           5
# dtype: int64
# Null details
# ************For Data***********
# Unnamed: 0    0
# gene_0        0
# gene_1        0
# gene_2        0
# gene_3        0
#              ..
# gene_20526    0
# gene_20527    0
# gene_20528    0
# gene_20529    0
# gene_20530    0
# Length: 20532, dtype: int64
#
# ...

# %%
# splitting dataset into training and testing part
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
test_data_ratio=[0.3,0.25,0.2,0.15,0.1,0.05]
for i in test_data_ratio:
    print("******************Start of iteration******************\n")
    print("For rati0 ",i)
    X_train, X_test, y_train, y_test=train_test_split(final_data.iloc[:,:80],final_data['label'],test_size=i,shuffle=True)
    base_estimator=GaussianNB(var_smoothing=1e-2)
    model = AdaBoostClassifier(base_estimator=base_estimator,n_estimators=130,learning_rate=1)
    # View the best parameters for the model found using grid search
    model=model.fit(X_train, y_train)
    Y_pred = model.predict(X_test)
    print(confusion_matrix(y_test,Y_pred))
    print("\n")
    print(classification_report(y_test,Y_pred))
    print("Training set score for GNB: %f" % model.score(X_train , y_train))
    print("Testing  set score for GNB: %f" % model.score(X_test  , y_test ))
    print("******************End of iteration******************\n")
# Out:
# ******************Start of iteration******************
#
# For rati0  0.3
# [[88  0  0  0  0]
#  [ 1 23  0  0  0]
#  [ 0  0 41  1  0]
#  [ 7  0  0 38  0]
#  [ 3  0  0  0 39]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        88
#            1       1.00      0.96      0.98        24
#            2       1.00      0.98      0.99        42
#            3       0.97      0.84      0.90        45
#            4       1.00      0.93      0.96        42
#
#     accuracy                           0.95       241
#    macro avg       0.97      0.94      0.96       241
# weighted avg       0.95      0.95      0.95       241
#
# Training set score for GNB: 0.967857
# Testing  set score for GNB: 0.950207
# ******************End of iteration******************
#
# ******************Start of iteration******************
#
# For rati0  0.25
# [[79  0  0  5  0]
#  [ 0 16  0  2  0]
#  [ 2  0 31  0  0]
#  [ 2  0  0 28  0]
# ...
