# %%
#Implementing Ensamble Learning

# %%
# Run this cell to get preprocessed data
# %run Dimension_Reduction.ipynb
# Out:
# Data loaded
# **************Details of data*************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Columns: 20532 entries, Unnamed: 0 to gene_20530
# dtypes: float64(20531), object(1)
# memory usage: 125.5+ MB
# None
#
# **************Details of labels*************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  801 non-null    object
#  1   Class       801 non-null    object
# dtypes: object(2)
# memory usage: 12.6+ KB
# None
# Unnamed: 0    801
# Class           5
# dtype: int64
# Null details
# ************For Data***********
# Unnamed: 0    0
# gene_0        0
# gene_1        0
# gene_2        0
# gene_3        0
#              ..
# gene_20526    0
# gene_20527    0
# gene_20528    0
# gene_20529    0
# gene_20530    0
# Length: 20532, dtype: int64
#
# **************For label************
# Unnamed: 0    0
# Class         0
# dtype: int64
# Columns dropped with all element 0
# PRAD 136
# LUAD 141
# BRCA 300
# KIRC 146
# COAD 78
# Normalization of data
# Dimension Reduction done
# Label Encoding done
# Finally, data preprocessing completed
# Final version of data is stored in 'final_data'
# final_data=    gene_9927  gene_9928  gene_9929  gene_993  gene_9930  gene_9931  gene_9932  \
# 0   0.074240   0.000000        0.0  0.317736   0.000000   0.000000   0.103426
# 1   0.000000   0.118172        0.0  0.611864   0.061145   0.178455   0.000000
# 2   0.000000   0.000000        0.0  0.457868   0.000000   0.396726   0.000000
# 3   0.000000   0.000000        0.0  0.549910   0.000000   0.315542   0.000000
# 4   0.045279   0.094607        0.0  0.657807   0.092543   0.435918   0.000000
#
#    gene_9933  gene_9934  gene_9935  ...  gene_9997  gene_9998  gene_9999  \
# 0   0.549063   0.157050   0.066993  ...   0.592891        0.0   0.429999
# 1   0.587582   0.000000   0.091812  ...   0.377247        0.0   0.477273
# 2   0.177371   0.525680   0.000000  ...   0.346013        0.0   0.558179
# 3   0.253207   0.275804   0.117650  ...   0.590198        0.0   0.625669
# 4   0.617929   0.000000   0.144411  ...   0.149630        0.0   0.587541
#
#    Class  BRCA  COAD  KIRC  LUAD  PRAD  label
# 0   PRAD     0     0     0     0     1      4
# 1   LUAD     0     0     0     1     0      3
# 2   PRAD     0     0     0     0     1      4
# 3   PRAD     0     0     0     0     1      4
# 4   BRCA     1     0     0     0     0      0
#
# [5 rows x 87 columns]

# %%
from sklearn.model_selection import train_test_split



from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import BaggingClassifier
from matplotlib import pyplot

# %%
# splitting dataset into training and testing part

test_data_ratio=[0.3,0.25,0.2,0.15,0.1,0.05]
for i in test_data_ratio:
    print("******************Start of iteration******************\n")
    print("For ratio ",i)
    X_train, X_test, y_train, y_test=train_test_split(final_data.iloc[:,:80],final_data['label'],test_size=i,shuffle=True)
    model = BaggingClassifier(KNeighborsClassifier(n_neighbors=5,leaf_size=10), max_samples= 0.5,max_features=0.4)
    model.fit(X_train,y_train)
    Y_pred = model.predict(X_test)
    print(confusion_matrix(y_test,Y_pred))
    print("\n")
    print(classification_report(y_test,Y_pred))
    print("Training set score for GNB: %f" % model.score(X_train , y_train))
    print("Testing  set score for GNB: %f" % model.score(X_test  , y_test ))
   
    print("******************End of iteration******************\n")
# Out:
# ******************Start of iteration******************
#
# For ratio  0.3
# [[95  0  0  1  0]
#  [ 1 23  0  0  0]
#  [ 0  0 37  0  1]
#  [16  0  0 26  0]
#  [ 0  0  0  0 41]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91        96
#            1       1.00      0.96      0.98        24
#            2       1.00      0.97      0.99        38
#            3       0.96      0.62      0.75        42
#            4       0.98      1.00      0.99        41
#
#     accuracy                           0.92       241
#    macro avg       0.96      0.91      0.92       241
# weighted avg       0.93      0.92      0.92       241
#
# Training set score for GNB: 0.957143
# Testing  set score for GNB: 0.921162
# ******************End of iteration******************
#
# ******************Start of iteration******************
#
# For ratio  0.25
# [[75  0  0  0  0]
#  [ 0 16  0  1  0]
#  [ 2  0 39  0  0]
#  [15  0  0 20  1]
#  [ 0  0  0  0 32]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90        75
#            1       1.00      0.94      0.97        17
#            2       1.00      0.95      0.97        41
#            3       0.95      0.56      0.70        36
#            4       0.97      1.00      0.98        32
#
#     accuracy                           0.91       201
#    macro avg       0.95      0.89      0.91       201
# weighted avg       0.92      0.91      0.90       201
#
# Training set score for GNB: 0.943333
# Testing  set score for GNB: 0.905473
# ******************End of iteration******************
#
# ******************Start of iteration******************
#
# For ratio  0.2
# [[60  0  0  1  0]
#  [ 0 20  0  0  0]
#  [ 1  0 25  0  0]
#  [ 3  0  0 18  1]
#  [ 0  0  0  0 32]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        61
#            1       1.00      1.00      1.00        20
#            2       1.00      0.96      0.98        26
#            3       0.95      0.82      0.88        22
#            4       0.97      1.00      0.98        32
#
#     accuracy                           0.96       161
#    macro avg       0.97      0.95      0.96       161
# weighted avg       0.96      0.96      0.96       161
#
# Training set score for GNB: 0.951562
# Testing  set score for GNB: 0.962733
# ******************End of iteration******************
#
# ******************Start of iteration******************
#
# For ratio  0.15
# [[38  1  0  1  1]
#  [ 0 16  0  0  0]
#  [ 0  0 26  0  0]
#  [ 6  0  0 16  1]
#  [ 0  0  0  0 15]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89        41
#            1       0.94      1.00      0.97        16
#            2       1.00      1.00      1.00        26
#            3       0.94      0.70      0.80        23
#            4       0.88      1.00      0.94        15
#
#     accuracy                           0.92       121
#    macro avg       0.93      0.92      0.92       121
# weighted avg       0.92      0.92      0.91       121
#
# Training set score for GNB: 0.951471
# Testing  set score for GNB: 0.917355
# ******************End of iteration******************
#
# ******************Start of iteration******************
#
# For ratio  0.1
# [[28  0  0  0  0]
#  [ 1  5  0  0  0]
#  [ 0  0 18  0  0]
#  [ 3  0  0 13  2]
#  [ 0  0  0  0 11]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93        28
#            1       1.00      0.83      0.91         6
#            2       1.00      1.00      1.00        18
#            3       1.00      0.72      0.84        18
#            4       0.85      1.00      0.92        11
#
#     accuracy                           0.93        81
#    macro avg       0.94      0.91      0.92        81
# weighted avg       0.94      0.93      0.92        81
#
# Training set score for GNB: 0.956944
# Testing  set score for GNB: 0.925926
# ******************End of iteration******************
#
# ******************Start of iteration******************
#
# For ratio  0.05
# [[16  0  0  0  0]
#  [ 0  4  0  0  0]
#  [ 0  0  8  0  0]
#  [ 1  0  0  5  0]
#  [ 0  0  0  0  7]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        16
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         8
#            3       1.00      0.83      0.91         6
#            4       1.00      1.00      1.00         7
#
#     accuracy                           0.98        41
#    macro avg       0.99      0.97      0.98        41
# weighted avg       0.98      0.98      0.97        41
#
# Training set score for GNB: 0.955263
# Testing  set score for GNB: 0.975610
# ******************End of iteration******************
