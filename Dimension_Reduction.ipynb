# %%
# Import all important libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load_data
def load_data():
    data=pd.read_csv(r"C:\Users\luhar\DAA project\DNA Sequencing\data_folder\data.csv")
    label=pd.read_csv(r"C:\Users\luhar\DAA project\DNA Sequencing\data_folder\labels.csv")
    return data,label

data,label=load_data()
print("Data loaded")
# Out:
# Data loaded

# %%
#Print details of data
print("**************Details of data*************")
print(data.info())
print()
print("**************Details of labels*************")
print(label.info())
print(label.nunique())
# Out:
# **************Details of data*************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Columns: 20532 entries, Unnamed: 0 to gene_20530
# dtypes: float64(20531), object(1)
# memory usage: 125.5+ MB
# None
#
# **************Details of labels*************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  801 non-null    object
#  1   Class       801 non-null    object
# dtypes: object(2)
# memory usage: 12.6+ KB
# None
# Unnamed: 0    801
# Class           5
# dtype: int64

# %%
#check for null values
print("Null details")
print("************For Data***********")
print(data.isnull().sum())
print()
print("**************For label************")
print(label.isnull().sum())
# Out:
# Null details
# ************For Data***********
# Unnamed: 0    0
# gene_0        0
# gene_1        0
# gene_2        0
# gene_3        0
#              ..
# gene_20526    0
# gene_20527    0
# gene_20528    0
# gene_20529    0
# gene_20530    0
# Length: 20532, dtype: int64
#
# **************For label************
# Unnamed: 0    0
# Class         0
# dtype: int64

# %%
#dropping columns:
print("Columns dropped with all element 0")
def drop_columns(data):
    for col in data.columns:
        if data[col].sum()==0:
            data.drop(col,axis=1,inplace=True)
    return data
data=drop_columns(data)
# Out:
# Columns dropped with all element 0

# %%
for uni in label['Class'].unique():
    print(uni, len(label[label['Class']==uni]))
# Out:
# PRAD 136
# LUAD 141
# BRCA 300
# KIRC 146
# COAD 78

# %%
# Normalizing data
print("Normalization of data")
for col in data.columns[1:]:
    maxi=data[col].max()
    mini=data[col].min()
    data[col]=(data[col]-mini)/(maxi-mini)
# Out:
# Normalization of data

# %%
encoding=pd.get_dummies(label['Class'])
X=data.iloc[:,1:]

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(random_state=2,max_depth=5)
model.fit(X,encoding)
print("Dimension Reduction done")
# Out:
# Dimension Reduction done

# %%
import numpy as np
features=X.columns
importances=model.feature_importances_
indices = np.argsort(importances)[-20:]  # top 80 features
# plt.title('Feature Importances')
# plt.barh(range(len(indices)), importances[indices], color='b', align='center')
# plt.yticks(range(len(indices)), [features[i] for i in indices])
# plt.xlabel('Relative Importance')
# plt.show()

# %%
important_col=pd.DataFrame({"col_name":features,"importance":importances})

# %%
important_col=pd.DataFrame(np.sort(important_col,axis=0),columns=["col_name","importance"]).iloc[-80:]

# %%
final_data=pd.DataFrame()
for i in important_col.col_name:
    final_data = pd.concat([final_data,data[i] ], join = 'outer', axis = 1)

# %%
final_data=pd.concat([final_data,label['Class']],join = 'outer', axis = 1)
# Out:
#      gene_9927  gene_9928  gene_9929  gene_993  gene_9930  gene_9931  \
# 0     0.074240   0.000000        0.0  0.317736   0.000000   0.000000
# 1     0.000000   0.118172        0.0  0.611864   0.061145   0.178455
# 2     0.000000   0.000000        0.0  0.457868   0.000000   0.396726
# 3     0.000000   0.000000        0.0  0.549910   0.000000   0.315542
# 4     0.045279   0.094607        0.0  0.657807   0.092543   0.435918
# ..         ...        ...        ...       ...        ...        ...
# 796   0.000000   0.000000        0.0  0.653722   0.000000   0.150853
# 797   0.000000   0.000000        0.0  0.497166   0.000000   0.000000
# 798   0.073591   0.231418        0.0  0.633624   0.188383   0.402267
# 799   0.124844   0.084772        0.0  0.632363   0.000000   0.000000
# 800   0.000000   0.000000        0.0  0.592266   0.077843   0.000000
#
#      gene_9932  gene_9933  gene_9934  gene_9935  ...  gene_9991  gene_9992  \
# 0     0.103426   0.549063   0.157050   0.066993  ...   0.668354   0.414082
# 1     0.000000   0.587582   0.000000   0.091812  ...   0.000000   0.517589
# 2     0.000000   0.177371   0.525680   0.000000  ...   0.000000   0.179625
# 3     0.000000   0.253207   0.275804   0.117650  ...   0.147317   0.173815
# 4     0.000000   0.617929   0.000000   0.144411  ...   0.711648   0.183219
# ..         ...        ...        ...        ...  ...        ...        ...
# 796   0.000000   0.308183   0.000000   0.290804  ...   0.679571   0.083097
# 797   0.000000   0.351436   0.000000   0.000000  ...   0.553827   0.230918
# 798   0.000000   0.736460   0.155676   0.149986  ...   0.100881   0.556291
# 799   0.173924   0.632533   0.000000   0.148992  ...   0.281672   0.220119
# 800   0.000000   0.532988   0.000000   0.241923  ...   0.341594   0.422392
#
#      gene_9993  gene_9994  gene_9995  gene_9996  gene_9997  gene_9998  \
# 0     0.421306   0.351712   0.798803   0.202244   0.592891   0.000000
# 1     0.341401   0.498018   0.098906   0.064792   0.377247   0.000000
# 2     0.521516   0.376065   0.393248   0.159468   0.346013   0.000000
# 3     0.304860   0.203918   0.401191   0.000000   0.590198   0.000000
# 4     0.444543   0.254238   0.428057   0.072264   0.149630   0.000000
# ..         ...        ...        ...        ...        ...        ...
# 796   0.379923   0.186554   0.375707   0.000000   0.000000   0.000000
# 797   0.000000   0.265535   0.828904   0.000000   0.380052   0.000000
# 798   0.478408   0.904234   0.593651   0.000000   0.590910   0.352102
# 799   0.921673   0.289734   0.857993   0.000000   0.000000   0.000000
# 800   0.847582   0.432324   0.476442   0.000000   0.436354   0.000000
#
#      gene_9999  Class
# 0     0.429999   PRAD
# 1     0.477273   LUAD
# 2     0.558179   PRAD
# 3     0.625669   PRAD
# 4     0.587541   BRCA
# ..         ...    ...
# 796   0.375947   BRCA
# 797   0.838456   LUAD
# 798   0.567780   COAD
# 799   0.534030   PRAD
# 800   0.615695   PRAD
#
# [801 rows x 81 columns]

# %%
final_data = pd.concat([final_data,encoding ], join = 'outer', axis = 1)
# Out:
#      gene_9927  gene_9928  gene_9929  gene_993  gene_9930  gene_9931  \
# 0     0.074240   0.000000        0.0  0.317736   0.000000   0.000000
# 1     0.000000   0.118172        0.0  0.611864   0.061145   0.178455
# 2     0.000000   0.000000        0.0  0.457868   0.000000   0.396726
# 3     0.000000   0.000000        0.0  0.549910   0.000000   0.315542
# 4     0.045279   0.094607        0.0  0.657807   0.092543   0.435918
# ..         ...        ...        ...       ...        ...        ...
# 796   0.000000   0.000000        0.0  0.653722   0.000000   0.150853
# 797   0.000000   0.000000        0.0  0.497166   0.000000   0.000000
# 798   0.073591   0.231418        0.0  0.633624   0.188383   0.402267
# 799   0.124844   0.084772        0.0  0.632363   0.000000   0.000000
# 800   0.000000   0.000000        0.0  0.592266   0.077843   0.000000
#
#      gene_9932  gene_9933  gene_9934  gene_9935  ...  gene_9996  gene_9997  \
# 0     0.103426   0.549063   0.157050   0.066993  ...   0.202244   0.592891
# 1     0.000000   0.587582   0.000000   0.091812  ...   0.064792   0.377247
# 2     0.000000   0.177371   0.525680   0.000000  ...   0.159468   0.346013
# 3     0.000000   0.253207   0.275804   0.117650  ...   0.000000   0.590198
# 4     0.000000   0.617929   0.000000   0.144411  ...   0.072264   0.149630
# ..         ...        ...        ...        ...  ...        ...        ...
# 796   0.000000   0.308183   0.000000   0.290804  ...   0.000000   0.000000
# 797   0.000000   0.351436   0.000000   0.000000  ...   0.000000   0.380052
# 798   0.000000   0.736460   0.155676   0.149986  ...   0.000000   0.590910
# 799   0.173924   0.632533   0.000000   0.148992  ...   0.000000   0.000000
# 800   0.000000   0.532988   0.000000   0.241923  ...   0.000000   0.436354
#
#      gene_9998  gene_9999  Class  BRCA  COAD  KIRC  LUAD  PRAD
# 0     0.000000   0.429999   PRAD     0     0     0     0     1
# 1     0.000000   0.477273   LUAD     0     0     0     1     0
# 2     0.000000   0.558179   PRAD     0     0     0     0     1
# 3     0.000000   0.625669   PRAD     0     0     0     0     1
# 4     0.000000   0.587541   BRCA     1     0     0     0     0
# ..         ...        ...    ...   ...   ...   ...   ...   ...
# 796   0.000000   0.375947   BRCA     1     0     0     0     0
# 797   0.000000   0.838456   LUAD     0     0     0     1     0
# 798   0.352102   0.567780   COAD     0     1     0     0     0
# 799   0.000000   0.534030   PRAD     0     0     0     0     1
# 800   0.000000   0.615695   PRAD     0     0     0     0     1
#
# [801 rows x 86 columns]

# %%
from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()

# encoding train labels 
encoder.fit(final_data['Class'])
Y_train = pd.DataFrame(encoder.transform(final_data['Class']))
final_data=pd.concat([final_data,Y_train ], join = 'outer', axis = 1)
final_data.rename(columns={0:"label"},inplace=True)
final_data
print("Label Encoding done")
print("Finally, data preprocessing completed ")
print("Final version of data is stored in 'final_data' ")
print("final_data=",final_data.head())
# Out:
# Label Encoding done
# Finally, data preprocessing completed
# Final version of data is stored in 'final_data'
# final_data=    gene_9927  gene_9928  gene_9929  gene_993  gene_9930  gene_9931  gene_9932  \
# 0   0.074240   0.000000        0.0  0.317736   0.000000   0.000000   0.103426
# 1   0.000000   0.118172        0.0  0.611864   0.061145   0.178455   0.000000
# 2   0.000000   0.000000        0.0  0.457868   0.000000   0.396726   0.000000
# 3   0.000000   0.000000        0.0  0.549910   0.000000   0.315542   0.000000
# 4   0.045279   0.094607        0.0  0.657807   0.092543   0.435918   0.000000
#
#    gene_9933  gene_9934  gene_9935  ...  gene_9998  gene_9999  Class  BRCA  \
# 0   0.549063   0.157050   0.066993  ...        0.0   0.429999   PRAD     0
# 1   0.587582   0.000000   0.091812  ...        0.0   0.477273   LUAD     0
# 2   0.177371   0.525680   0.000000  ...        0.0   0.558179   PRAD     0
# 3   0.253207   0.275804   0.117650  ...        0.0   0.625669   PRAD     0
# 4   0.617929   0.000000   0.144411  ...        0.0   0.587541   BRCA     1
#
#    COAD  KIRC  LUAD  PRAD  label  label
# 0     0     0     0     1      4      4
# 1     0     0     1     0      3      3
# 2     0     0     0     1      4      4
# 3     0     0     0     1      4      4
# 4     0     0     0     0      0      0
#
# [5 rows x 88 columns]
